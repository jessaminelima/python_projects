# %% [markdown]
# <a href="https://colab.research.google.com/github/jessaminelima/python_projects/blob/main/Open_and_Show.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow # for image display
import cv2 as cv

# Opening Image
input= cv.imread("/content/drive/MyDrive/Livros, Listas e Trabalhos/Disciplinas/Padrão de Compressão/Images/City_Wallpaper_2.jpg")

# resizing the image
output = cv2.resize(input, (640, 480))

# %%
# Displaying the resulting image
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F6E82B1BE50>
